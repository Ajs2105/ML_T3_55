# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('LiveLongerData.csv')
df.head()
# Out:
#               Factor  Years gained / lost strength of science?  \
# 0            Smoking                -10.0               strong
# 1       Sitting Down                 -3.0           suggestive
# 2  Too much sleeping                 -1.5           suggestive
# 3      More Optimism                  2.0           suggestive
# 4          More Pets                  3.0                 good
#
#    strength of science as a number sexes affected    effect  \
# 0                                3           Both  negative
# 1                                1           Both  negative
# 2                                1           Both  negative
# 3                                1         Female  positive
# 4                                2           Both  positive
#
#                                              Comment  \
# 0  10 years gained (against those who continue to...
# 1                       for 8-11 hours sitting a day
# 2          7 hours ideal, no more than 8 hrs a night
# ...

# %%
df['strength of science?'].is_unique
# Out:
# False

# %%
df = df.set_index('strength of science?')
df.head()
# Out:
#                                  Factor  Years gained / lost  \
# strength of science?
# strong                          Smoking                -10.0
# suggestive                 Sitting Down                 -3.0
# suggestive            Too much sleeping                 -1.5
# suggestive                More Optimism                  2.0
# good                          More Pets                  3.0
#
#                       strength of science as a number sexes affected  \
# strength of science?
# strong                                              3           Both
# suggestive                                          1           Both
# suggestive                                          1           Both
# suggestive                                          1         Female
# good                                                2           Both
#
#                         effect  \
# strength of science?
# strong                negative
# suggestive            negative
# ...

# %%
df = df.set_index('strength of science?')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4076\3654156226.py in ?()
# ----> 1 df = df.set_index('strength of science?')
#       2 df.head()
#
# c:\Users\ashwi\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['strength of science?'] are in the columns"

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("LiveLongerData.csv").convert_dtypes()

# %%
fig, ax = plt.subplots()
ax.scatter(data["effect"], data["Factor"])
ax.set_title("strength of science as a number")
ax.set_xlabel("sexes affected")
ax.set_ylabel("Comment")
fig.show()
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_4076\4073192435.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
